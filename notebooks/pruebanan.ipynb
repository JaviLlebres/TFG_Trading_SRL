# %%
import pandas as pd
df_check = pd.read_csv('../data/ETH/02-srl-temporal-ae-1h-from-2021-12-31_00-00-00-until-2025-07-31_00-00-00.csv')
print(f"¿Hay NaNs en el embedding?: {df_check.isnull().values.any()}")
print(df_check.describe()) # Mira si hay valores astronómicos (E+30)
# Out:
# ¿Hay NaNs en el embedding?: False
#        ae_embedding_0  ae_embedding_1  ae_embedding_2  ae_embedding_3  \
# count    29040.000000    29040.000000    29040.000000    29040.000000
# mean         0.192121        0.037002        0.129238       -0.009063
# std          0.197016        0.275617        0.164641        0.205704
# min         -0.712547       -1.335736       -0.410597       -0.943577
# 25%          0.070623       -0.140610        0.018112       -0.132044
# 50%          0.199361        0.049076        0.128449       -0.002476
# 75%          0.328092        0.223628        0.236818        0.130084
# max          0.860615        1.036786        0.787142        0.926581
#
#        ae_embedding_4  ae_embedding_5  ae_embedding_6  ae_embedding_7  \
# count    29040.000000    29040.000000    29040.000000    29040.000000
# mean        -0.066441       -0.136271        0.150699        0.029996
# std          0.196549        0.263313        0.289563        0.125409
# ...
